# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from scipy import signal
import matplotlib.pyplot as plt
import xarray as xr
from pyedflib import highlevel
from bibliotheque import *
import yasa
import tqdm
import mne

# %% [markdown]
# ## PARAMS

# %%
root = '/crnldata/'

# %%
input_file = root + 'cmo/Etudiants/Valentin_G/Sleep_EEG_Respi/dataarray/da_staged.nc'

# %%
save_df_spindles = False

# %%
save_presentation = False

# %% [markdown]
# ## LOAD

# %%
da = xr.load_dataarray(input_file)

# %%
chans = list(da.coords['chan'].values)
eeg_chans = ['Fp2-C4','C4-T4','T4-O2','Fz-Cz','Cz-Pz','Fp1-C3','C3-T3','T3-O1']
respi_chan = 'THERM'
ecg_chan = 'ECG'
eog_chans = ['EOGDt-A2','EOGG-A1']
stages = ['W','R','N1','N2','N3']
srate = 256

# %%
da
# Out:
# <xarray.DataArray (stage: 5, chan: 31, time: 3824640)>
# array([[[ 2.11088257e+00,  8.51014462e-01, -5.47029235e-01, ...,
#                      nan,             nan,             nan],
#         [ 4.07363403e+01,  4.19338072e+01,  4.20180019e+01, ...,
#                      nan,             nan,             nan],
#         [-6.92574386e+01, -7.74781380e+01, -8.20147635e+01, ...,
#                      nan,             nan,             nan],
#         ...,
#         [-3.73264297e-01, -3.72837881e-01, -3.73183356e-01, ...,
#                      nan,             nan,             nan],
#         [ 3.46511582e-01,  2.59730570e-01,  2.83769078e-01, ...,
#                      nan,             nan,             nan],
#         [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#                      nan,             nan,             nan]],
#
#        [[ 1.50529183e+02,  1.50191271e+02,  1.50805315e+02, ...,
#           4.74378435e+01,  4.22493246e+01,  4.91851192e+01],
#         [ 6.90894942e+01,  6.82894568e+01,  6.82945179e+01, ...,
#           7.79971626e+01,  8.94758315e+01,  1.10711616e+02],
#         [-6.08560311e+01, -5.40292796e+01, -5.20637536e+01, ...,
#          -1.32508244e+02, -1.29192576e+02, -1.46596305e+02],
# ...
#         [-3.70734734e-01, -3.66204027e-01, -3.68107580e-01, ...,
#                      nan,             nan,             nan],
#         [ 2.82175521e-01,  2.25135290e-01,  1.90934871e-01, ...,
#                      nan,             nan,             nan],
#         [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#                      nan,             nan,             nan]],
#
#        [[ 2.07541905e+01,  1.87138816e+01,  1.80900208e+01, ...,
#                      nan,             nan,             nan],
#         [ 2.13067778e+01,  2.30892791e+01,  2.41598862e+01, ...,
#                      nan,             nan,             nan],
#         [-4.04766405e+01, -4.45825300e+01, -4.95821768e+01, ...,
#                      nan,             nan,             nan],
#         ...,
#         [-3.68000182e-01, -3.67198267e-01, -3.68587554e-01, ...,
#                      nan,             nan,             nan],
#         [ 6.70865726e-01,  6.22768966e-01,  5.82221763e-01, ...,
#                      nan,             nan,             nan],
#         [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#                      nan,             nan,             nan]]])
# Coordinates:
#   * time     (time) float64 0.0 0.003906 0.007812 ... 1.494e+04 1.494e+04
#   * chan     (chan) object 'Fp2-C4' 'C4-T4' 'T4-O2' ... '-' 'ANNOTATION'
#   * stage    (stage) object 'N1' 'W' 'N2' 'R' 'N3'

# %% [markdown]
# ## SEL N2 DATA

# %%
da_N2 = da.sel(stage = 'N2').dropna(dim='time')

# %%
da_N2
# Out:
# <xarray.DataArray (chan: 31, time: 2265600)>
# array([[ 1.57316828e+01,  1.21813412e+01,  9.38920537e+00, ...,
#          3.64174308e+01,  3.62686147e+01,  3.74392899e+01],
#        [ 5.83001757e+01,  5.72083252e+01,  5.58677758e+01, ...,
#          6.34570823e+01,  6.30250709e+01,  6.05690957e+01],
#        [-1.19060935e+02, -1.19908883e+02, -1.20117212e+02, ...,
#         -1.05141774e+02, -1.05864632e+02, -1.06282370e+02],
#        ...,
#        [-3.68261630e-01, -3.65724343e-01, -3.68702077e-01, ...,
#         -3.74185157e-01, -3.75672758e-01, -3.75346825e-01],
#        [ 2.69694168e-01,  2.59228093e-01,  2.38982679e-01, ...,
#          2.64224363e-01,  2.60077143e-01,  2.87141293e-01],
#        [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#          8.23987182e-02,  8.23987182e-02,  8.23987182e-02]])
# Coordinates:
#   * time     (time) float64 0.0 0.003906 0.007812 ... 8.85e+03 8.85e+03 8.85e+03
#   * chan     (chan) object 'Fp2-C4' 'C4-T4' 'T4-O2' ... '-' 'ANNOTATION'
#     stage    <U2 'N2'

# %%
data = da_N2.sel(chan = eeg_chans).values
chan = eeg_chans

# %% [markdown]
# ## FIND SPINDLES WITH YASA

# %%
# Apply the detection
sp = yasa.spindles_detect(data=data, sf=srate, ch_names=chan, multi_only=False)

# Get the full detection dataframe
all_spindles = sp.summary()  
all_spindles
# Out:
#             Start         Peak          End  Duration  Amplitude        RMS  \
# 0       59.062500    59.421875    59.949219  0.886719  50.552506   9.198861
# 1       61.679688    62.152344    62.363281  0.683594  45.307265  11.034409
# 2       65.433594    65.742188    66.015625  0.582031  44.304907  10.309570
# 3       67.644531    67.765625    68.296875  0.652344  48.667588  11.655442
# 4       87.617188    87.996094    88.328125  0.710938  50.774271  10.271449
# ...           ...          ...          ...       ...        ...        ...
# 3152  8070.269531  8070.687500  8070.871094  0.601562  37.650290   8.835626
# 3153  8292.859375  8293.003906  8293.625000  0.765625  38.533010   9.228405
# 3154  8372.921875  8373.269531  8373.558594  0.636719  48.351797  10.112342
# 3155  8390.382812  8390.726562  8391.035156  0.652344  70.508474  15.496380
# 3156  8601.660156  8602.257812  8602.429688  0.769531  55.876462  12.462484
#
#       AbsPower  RelPower  Frequency  Oscillations  Symmetry Channel  \
# 0     1.681068  0.273213  13.133185           9.0  0.403509  Fp2-C4
# 1     2.248550  0.552724  12.831217           9.0  0.687500  Fp2-C4
# 2     2.206761  0.374857  13.944192           8.0  0.526667  Fp2-C4
# 3     2.139001  0.361876  14.613895           8.0  0.184524  Fp2-C4
# 4     1.864004  0.237175  13.915164           7.0  0.530055  Fp2-C4
# ...        ...       ...        ...           ...       ...     ...
# 3152  1.854641  0.254221  14.052198           6.0  0.690323   T3-O1
# 3153  1.740058  0.229788  13.896299          10.0  0.187817   T3-O1
# 3154  1.877038  0.283629  14.457036           9.0  0.542683   T3-O1
# 3155  2.465284  0.384927  13.893178           8.0  0.523810   T3-O1
# 3156  1.994073  0.287764  13.846166          10.0  0.772727   T3-O1
#
#       IdxChannel
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ...          ...
# 3152           7
# 3153           7
# 3154           7
# 3155           7
# 3156           7
#
# [3157 rows x 13 columns]

# %%
sp.summary(grp_chan=True, aggfunc='mean')
# Out:
#          Count  Duration  Amplitude        RMS  AbsPower  RelPower  Frequency  \
# Channel
# C3-T3      452  0.925660  45.223435   9.740679  1.941592  0.412509  14.023069
# C4-T4      482  0.902303  42.022376   9.055902  1.876500  0.401576  13.991966
# Cz-Pz      173  0.759280  37.209045   8.221203  1.768698  0.342353  13.591147
# Fp1-C3     614  0.876139  55.324246  11.871572  2.101484  0.413017  13.557511
# Fp2-C4     603  0.860969  56.127451  12.056505  2.124560  0.409373  13.512821
# Fz-Cz      600  0.880260  50.734868  10.910995  2.041192  0.410164  13.794668
# T3-O1      117  0.763956  57.200814  12.308761  2.104364  0.335666  13.845572
# T4-O2      116  0.759934  57.059096  12.428865  2.129679  0.342326  13.937836
#
#          Oscillations  Symmetry
# Channel
# C3-T3       11.847345  0.476753
# C4-T4       11.410788  0.486580
# Cz-Pz        9.554913  0.468546
# Fp1-C3      11.078176  0.480644
# Fp2-C4      10.837479  0.486951
# Fz-Cz       11.286667  0.484009
# T3-O1        9.709402  0.514176
# T4-O2        9.784483  0.507550

# %%
sp.plot_average(center='Peak', time_before=1, time_after=1)
# Out:
# <AxesSubplot:title={'center':'Average spindle'}, xlabel='Time (sec)', ylabel='Amplitude (uV)'>

# %%
sp_multi = yasa.spindles_detect(data=data, sf=srate, ch_names=chan, multi_only=True, remove_outliers=True)
all_spindles = sp_multi.summary()
print(all_spindles.shape[0], 'spindles detected that are common to at least two electrodes.')
all_spindles.head().round(3)
# Out:
# 2269 spindles detected that are common to at least two electrodes.
#      Start     Peak      End  Duration  Amplitude     RMS  AbsPower  RelPower  \
# 0   61.680   62.152   62.363     0.684     45.307  11.034     2.249     0.553
# 1   65.434   65.742   66.016     0.582     44.305  10.310     2.207     0.375
# 2   67.645   67.766   68.297     0.652     48.668  11.655     2.139     0.362
# 3   87.617   87.996   88.328     0.711     50.774  10.271     1.864     0.237
# 4  114.316  114.816  115.270     0.953     70.634  14.186     2.372     0.417
#
#    Frequency  Oscillations  Symmetry Channel  IdxChannel
# 0     12.831           9.0     0.688  Fp2-C4           0
# 1     13.944           8.0     0.527  Fp2-C4           0
# 2     14.614           8.0     0.185  Fp2-C4           0
# 3     13.915           7.0     0.530  Fp2-C4           0
# 4     14.718          13.0     0.522  Fp2-C4           0

# %%
sp.summary(grp_chan=True)
# Out:
#          Count  Duration  Amplitude        RMS  AbsPower  RelPower  Frequency  \
# Channel
# C3-T3      452  0.925660  45.223435   9.740679  1.941592  0.412509  14.023069
# C4-T4      482  0.902303  42.022376   9.055902  1.876500  0.401576  13.991966
# Cz-Pz      173  0.759280  37.209045   8.221203  1.768698  0.342353  13.591147
# Fp1-C3     614  0.876139  55.324246  11.871572  2.101484  0.413017  13.557511
# Fp2-C4     603  0.860969  56.127451  12.056505  2.124560  0.409373  13.512821
# Fz-Cz      600  0.880260  50.734868  10.910995  2.041192  0.410164  13.794668
# T3-O1      117  0.763956  57.200814  12.308761  2.104364  0.335666  13.845572
# T4-O2      116  0.759934  57.059096  12.428865  2.129679  0.342326  13.937836
#
#          Oscillations  Symmetry
# Channel
# C3-T3       11.847345  0.476753
# C4-T4       11.410788  0.486580
# Cz-Pz        9.554913  0.468546
# Fp1-C3      11.078176  0.480644
# Fp2-C4      10.837479  0.486951
# Fz-Cz       11.286667  0.484009
# T3-O1        9.709402  0.514176
# T4-O2        9.784483  0.507550

# %%
from functools import reduce
grp_start = all_spindles.groupby('Channel')['Start'].apply(lambda x: list(np.round(x).astype(int))).to_dict()
grp_end = all_spindles.groupby('Channel')['End'].apply(lambda x: list(np.round(x).astype(int))).to_dict()

intersect_start = reduce(np.intersect1d, (grp_start[c] for c in all_spindles['Channel'].unique()))
intersect_end = reduce(np.intersect1d, (grp_end[c] for c in all_spindles['Channel'].unique()))

idx_start = np.in1d(all_spindles['Start'].round().astype(int), intersect_start)
idx_end = np.in1d(all_spindles['End'].round().astype(int), intersect_end)
idx_good = np.logical_or(idx_start, idx_end)

# Now we keep only these spindles in the dataframe
print(all_spindles[idx_good].shape[0], 'unique spindles are common across ALL channels.')
all_spindles[idx_good].head().round(3)
# Out:
# 16 unique spindles are common across ALL channels.
#         Start      Peak       End  Duration  Amplitude     RMS  AbsPower  \
# 150  3687.172  3687.375  3688.227     1.055     35.892   8.455     1.787
# 168  4089.766  4090.016  4090.699     0.934     52.706  11.300     2.207
# 536  3687.098  3687.691  3688.277     1.180     37.405   8.479     1.876
# 548  4089.617  4090.117  4090.707     1.090     51.638  11.321     2.125
# 808  3686.941  3687.230  3687.785     0.844     60.511  13.867     2.302
#
#      RelPower  Frequency  Oscillations  Symmetry Channel  IdxChannel
# 150     0.344     13.978          13.0     0.192  Fp2-C4           0
# 168     0.582     14.198          12.0     0.267  Fp2-C4           0
# 536     0.417     14.114          15.0     0.502   C4-T4           1
# 548     0.522     14.274          14.0     0.457   C4-T4           1
# 808     0.469     13.971          11.0     0.341   T4-O2           2

# %%
all_spindles[idx_good]
# Out:
#             Start         Peak          End  Duration  Amplitude        RMS  \
# 150   3687.171875  3687.375000  3688.226562  1.054688  35.892254   8.455178
# 168   4089.765625  4090.015625  4090.699219  0.933594  52.706188  11.299895
# 536   3687.097656  3687.691406  3688.277344  1.179688  37.404556   8.479006
# 548   4089.617188  4090.117188  4090.707031  1.089844  51.637533  11.320849
# 808   3686.941406  3687.230469  3687.785156  0.843750  60.510693  13.866843
# 816   4089.929688  4090.156250  4090.546875  0.617188  59.554999  15.293982
# 1023  3686.890625  3687.226562  3687.746094  0.855469  42.209305  10.436204
# 1036  4089.796875  4090.011719  4090.820312  1.023438  54.887817  11.037395
# 1350  3687.113281  3687.230469  3687.640625  0.527344  43.576871  10.874411
# 1359  4089.835938  4090.214844  4090.562500  0.726562  37.325375   7.350860
# 1590  3686.960938  3687.226562  3688.039062  1.078125  49.018322  11.493216
# 1607  4089.796875  4090.007812  4090.679688  0.882812  67.882497  13.275438
# 1968  3687.101562  3687.972656  3688.296875  1.195312  50.096577  10.730390
# 1981  4089.683594  4090.195312  4090.582031  0.898438  45.228792  10.123461
# 2217  3686.949219  3687.375000  3687.921875  0.972656  55.119508  13.448578
# 2228  4089.960938  4090.226562  4090.621094  0.660156  47.026328  10.928064
#
#       AbsPower  RelPower  Frequency  Oscillations  Symmetry Channel  \
# 150   1.786641  0.344047  13.977550          13.0  0.191882  Fp2-C4
# 168   2.206694  0.582119  14.198348          12.0  0.266667  Fp2-C4
# 536   1.876304  0.416657  14.113652          15.0  0.501650   C4-T4
# 548   2.124767  0.521631  14.274298          14.0  0.457143   C4-T4
# 808   2.302260  0.468766  13.970690          11.0  0.341014   T4-O2
# 816   2.480206  0.384664  13.948124           9.0  0.364780   T4-O2
# 1023  2.027745  0.445499  14.103624          10.0  0.390909   Fz-Cz
# 1036  2.196571  0.563903  14.193453          15.0  0.209125   Fz-Cz
# 1350  2.066133  0.250564  14.142898           7.0  0.220588   Cz-Pz
# 1359  1.794703  0.390875  13.881640          10.0  0.518717   Cz-Pz
# 1590  2.029681  0.365588  14.109671          14.0  0.245487  Fp1-C3
# 1607  2.226970  0.501790  14.251113          12.0  0.237885  Fp1-C3
# 1968  1.971577  0.374960  14.024767          17.0  0.726384   C3-T3
# 1981  2.056302  0.414679  14.339855          13.0  0.567100   C3-T3
# 2217  2.246339  0.433845  13.982535          12.0  0.436000   T3-O1
# 2228  2.132444  0.379381  14.088302           9.0  0.400000   T3-O1
#
#       IdxChannel
# 150            0
# 168            0
# 536            1
# 548            1
# 808            2
# 816            2
# 1023           3
# 1036           3
# 1350           4
# 1359           4
# 1590           5
# 1607           5
# 1968           6
# 1981           6
# 2217           7
# 2228           7

# %%
plt.figure()
da_N2.loc[eeg_chans , 4089:4091].plot.line(x='time' , hue = 'chan')
plt.title('Spindle window')
if save_presentation:
    plt.savefig('../presentation/exp_spindles')
plt.show()

# %%
def nspindle_by_stage(da_all, stages=stages, chan=eeg_chans, srate=srate):
    rows = []
    for stage in stages:
        da_stage = da_all.sel(stage=stage, chan = chan).dropna(dim='time')
        tot_time_stage = da_stage.coords['time'].values[-1]
        data = da_stage.values
        # Apply the detection
        sp = yasa.spindles_detect(data=data, sf=srate, ch_names=chan, multi_only=False)

        # Get the full detection dataframe
        all_spindles = sp.summary()  
        
        grp_start = all_spindles.groupby('Channel')['Start'].apply(lambda x: list(np.round(x).astype(int))).to_dict()
        grp_end = all_spindles.groupby('Channel')['End'].apply(lambda x: list(np.round(x).astype(int))).to_dict()

        intersect_start = reduce(np.intersect1d, (grp_start[c] for c in all_spindles['Channel'].unique()))
        intersect_end = reduce(np.intersect1d, (grp_end[c] for c in all_spindles['Channel'].unique()))

        idx_start = np.in1d(all_spindles['Start'].round().astype(int), intersect_start)
        idx_end = np.in1d(all_spindles['End'].round().astype(int), intersect_end)
        idx_good = np.logical_or(idx_start, idx_end)

        # Now we keep only these spindles in the dataframe
        nspindles_in_whole_brain = all_spindles[idx_good].shape[0]
        nspindles_all = all_spindles.shape[0]
        
        row = [ stage, nspindles_all , nspindles_in_whole_brain , int(tot_time_stage)]
        rows.append(row)
    df = pd.DataFrame(rows, columns = ['stage' , 'tot spindles found', 'tot common spindles' , 'total time sig'])
    return df

# %%
df = nspindle_by_stage(da_all=da)
# Out:
# 03-May-22 08:55:42 | WARNING | No spindle were found in channel Fp2-C4.
# 03-May-22 08:55:43 | WARNING | No spindle were found in channel C4-T4.
# 03-May-22 08:55:45 | WARNING | No spindle were found in channel Cz-Pz.
# 03-May-22 08:55:46 | WARNING | No spindle were found in channel Fp1-C3.
# 03-May-22 08:55:47 | WARNING | No spindle were found in channel T3-O1.
# 03-May-22 08:56:06 | WARNING | No spindle were found in channel T4-O2.
# 03-May-22 08:56:07 | WARNING | No spindle were found in channel T3-O1.

# %%
df
# Out:
#   stage  tot spindles found  tot common spindles  total time sig
# 0     W                1118                   16           14939
# 1     R                   6                    0            5159
# 2    N1                  38                    0             119
# 3    N2                3157                  128            8849
# 4    N3                  71                    0            2639

# %% [markdown]
# Spindles ++ en N2 , et ce même en proportion sur le temps de signal

# %%
da_to_study = da.sel(stage = 'N2').dropna(dim='time')

# %%
da_to_study
# Out:
# <xarray.DataArray (chan: 31, time: 2265600)>
# array([[ 1.57316828e+01,  1.21813412e+01,  9.38920537e+00, ...,
#          3.64174308e+01,  3.62686147e+01,  3.74392899e+01],
#        [ 5.83001757e+01,  5.72083252e+01,  5.58677758e+01, ...,
#          6.34570823e+01,  6.30250709e+01,  6.05690957e+01],
#        [-1.19060935e+02, -1.19908883e+02, -1.20117212e+02, ...,
#         -1.05141774e+02, -1.05864632e+02, -1.06282370e+02],
#        ...,
#        [-3.68261630e-01, -3.65724343e-01, -3.68702077e-01, ...,
#         -3.74185157e-01, -3.75672758e-01, -3.75346825e-01],
#        [ 2.69694168e-01,  2.59228093e-01,  2.38982679e-01, ...,
#          2.64224363e-01,  2.60077143e-01,  2.87141293e-01],
#        [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#          8.23987182e-02,  8.23987182e-02,  8.23987182e-02]])
# Coordinates:
#   * time     (time) float64 0.0 0.003906 0.007812 ... 8.85e+03 8.85e+03 8.85e+03
#   * chan     (chan) object 'Fp2-C4' 'C4-T4' 'T4-O2' ... '-' 'ANNOTATION'
#     stage    <U2 'N2'

# %%
def spindles_from_stage(da, stage, srate=srate, chan = eeg_chans, save=False):  
    data = da.sel(stage = stage, chan = chan).dropna(dim='time').values
    
    # Apply the detection
    sp = yasa.spindles_detect(data=data, sf=srate, ch_names=chan, multi_only=False)

    # Get the full detection dataframe
    all_spindles = sp.summary()  
    all_spindles.insert(0 , 'stage', stage)
    if save: 
        all_spindles.to_excel(root + f'cmo/Etudiants/Valentin_G/Sleep_EEG_Respi/df_analyse/spindles_{stage}.xlsx')
    return all_spindles

# %%
spindles = spindles_from_stage(da=da, stage = 'N2', save=save_df_spindles)

# %%
spindles
# Out:
#      stage        Start         Peak          End  Duration  Amplitude  \
# 0       N2    59.062500    59.421875    59.949219  0.886719  50.552506
# 1       N2    61.679688    62.152344    62.363281  0.683594  45.307265
# 2       N2    65.433594    65.742188    66.015625  0.582031  44.304907
# 3       N2    67.644531    67.765625    68.296875  0.652344  48.667588
# 4       N2    87.617188    87.996094    88.328125  0.710938  50.774271
# ...    ...          ...          ...          ...       ...        ...
# 3152    N2  8070.269531  8070.687500  8070.871094  0.601562  37.650290
# 3153    N2  8292.859375  8293.003906  8293.625000  0.765625  38.533010
# 3154    N2  8372.921875  8373.269531  8373.558594  0.636719  48.351797
# 3155    N2  8390.382812  8390.726562  8391.035156  0.652344  70.508474
# 3156    N2  8601.660156  8602.257812  8602.429688  0.769531  55.876462
#
#             RMS  AbsPower  RelPower  Frequency  Oscillations  Symmetry  \
# 0      9.198861  1.681068  0.273213  13.133185           9.0  0.403509
# 1     11.034409  2.248550  0.552724  12.831217           9.0  0.687500
# 2     10.309570  2.206761  0.374857  13.944192           8.0  0.526667
# 3     11.655442  2.139001  0.361876  14.613895           8.0  0.184524
# 4     10.271449  1.864004  0.237175  13.915164           7.0  0.530055
# ...         ...       ...       ...        ...           ...       ...
# 3152   8.835626  1.854641  0.254221  14.052198           6.0  0.690323
# 3153   9.228405  1.740058  0.229788  13.896299          10.0  0.187817
# 3154  10.112342  1.877038  0.283629  14.457036           9.0  0.542683
# 3155  15.496380  2.465284  0.384927  13.893178           8.0  0.523810
# 3156  12.462484  1.994073  0.287764  13.846166          10.0  0.772727
#
#      Channel  IdxChannel
# 0     Fp2-C4           0
# 1     Fp2-C4           0
# 2     Fp2-C4           0
# 3     Fp2-C4           0
# 4     Fp2-C4           0
# ...      ...         ...
# 3152   T3-O1           7
# 3153   T3-O1           7
# 3154   T3-O1           7
# 3155   T3-O1           7
# 3156   T3-O1           7
#
# [3157 rows x 14 columns]

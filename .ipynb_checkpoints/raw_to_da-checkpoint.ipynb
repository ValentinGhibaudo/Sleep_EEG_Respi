# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from scipy import signal
import matplotlib.pyplot as plt
import xarray as xr
from pyedflib import highlevel
from bibliotheque import *
import yasa
import tqdm

# %%
def eeg_mono_to_bipol(da, dérivations):
    da_bipol = []
    for bipol in dérivations : 
        pole1, pole2 = bipol.split('-')[0] , bipol.split('-')[1]
        if pole1 in ['EOGDt','EOGG']:
            chan1 = pole1
            chan2 = f'EEG {pole2}'
        else:
            chan1 = f'EEG {pole1}'
            chan2 = f'EEG {pole2}'
        sig1 = da.loc[chan1,:]
        sig2 = da.loc[chan2,:]
        bipol_sig = sig1 - sig2
        da_bipol.append(bipol_sig)
    da_bipolaire = xr.concat(da_bipol, dim = 'chan')
    da_bipolaire = da_bipolaire.assign_coords({'chan':dérivations})
    return da_bipolaire

# %%
root = '/crnldata/'

# %%
input_file = root + 'cmo/Etudiants/Valentin_G/Sleep_EEG_Respi/data/190722B-A_bis.EDF'
# input_file = root + 'cmo/Etudiants/Valentin_G/Sleep_EEG_Respi/data/190722B-A.edf'

# %%
signals, signal_headers, header = highlevel.read_edf(input_file)

# %%
srate = signal_headers[0]['sample_rate']
chans = [chan_dict['label'] for chan_dict in signal_headers]
eeg_chans = [ chan for chan in chans if 'EEG' in chan]
eeg_chans_clean = [ chan.split(' ')[1] for chan in chans if 'EEG' in chan]
eog_chans = [ chan for chan in chans if 'EOG' in chan] 
physio_chans = [ chan for chan in chans if not 'EEG' in chan] 
unit = signal_headers[0]['dimension']
time = np.arange(0 , signals.shape[1] / srate , 1 / srate)
dérivations = ['Fp2-C4' , 'C4-T4', 'T4-O2' , 'Fz-Cz' , 'Cz-Pz' , 'Fp1-C3', 'C3-T3', 'T3-O1', 'EOGDt-A2', 'EOGG-A1']
print(f'Total duration : {int(time[-1])} seconds')
print(f'Nb of eeg electrodes : {len(eeg_chans)}')
print(f'Nb physios electrodes : {len(physio_chans)}')
# Out:
# Total duration : 31779 seconds
# Nb of eeg electrodes : 13
# Nb physios electrodes : 21

# %%
physio_chans
# Out:
# ['ECG',
#  'Menton',
#  'EOGDt',
#  'EOGG',
#  'JBdt',
#  'JBg',
#  'THERM',
#  'SAT',
#  'THO',
#  'ABD',
#  'PTT',
#  'FC',
#  'Pouls',
#  'POS',
#  'Micro',
#  'PCO2',
#  'DEBIT',
#  'CPAP',
#  'PRESSION',
#  '-',
#  'ANNOTATION']

# %%
da = xr.DataArray(data = signals, dims = ['chan','time'] , coords = {'chan':chans , 'time':time})

# %%
da.loc[eeg_chans, 10:10.5].plot.line(x='time', hue = 'chan', size = 10)
# Out:
# [<matplotlib.lines.Line2D at 0x7f75e365b4c0>,
#  <matplotlib.lines.Line2D at 0x7f75e365b3d0>,
#  <matplotlib.lines.Line2D at 0x7f75e362e850>,
#  <matplotlib.lines.Line2D at 0x7f75e362e7c0>,
#  <matplotlib.lines.Line2D at 0x7f75e362e340>,
#  <matplotlib.lines.Line2D at 0x7f75e362e2e0>,
#  <matplotlib.lines.Line2D at 0x7f75e362e190>,
#  <matplotlib.lines.Line2D at 0x7f75e358a190>,
#  <matplotlib.lines.Line2D at 0x7f75e358a640>,
#  <matplotlib.lines.Line2D at 0x7f75e358ad60>,
#  <matplotlib.lines.Line2D at 0x7f75e365b520>,
#  <matplotlib.lines.Line2D at 0x7f75e358a610>,
#  <matplotlib.lines.Line2D at 0x7f75e358a700>]

# %%
plt.figure()
for chan in eeg_chans :
    f, Pxx = spectre(da.loc[chan,:].values, srate=srate, wsize = 50)
    plt.plot(f, Pxx)
plt.show()

# %%
da_bipol = eeg_mono_to_bipol(da, dérivations = dérivations)

# %%
da_bipol.loc[:,10:11].plot.line(x='time', hue = 'chan', size = 10)
# Out:
# [<matplotlib.lines.Line2D at 0x7f75e3598280>,
#  <matplotlib.lines.Line2D at 0x7f75e3598d90>,
#  <matplotlib.lines.Line2D at 0x7f75e3598a60>,
#  <matplotlib.lines.Line2D at 0x7f75e34e5d90>,
#  <matplotlib.lines.Line2D at 0x7f75e34e5c70>,
#  <matplotlib.lines.Line2D at 0x7f75e34e5df0>,
#  <matplotlib.lines.Line2D at 0x7f75e34e5490>,
#  <matplotlib.lines.Line2D at 0x7f75e34e53d0>,
#  <matplotlib.lines.Line2D at 0x7f75e34e50a0>,
#  <matplotlib.lines.Line2D at 0x7f75e34e5250>]

# %%
plt.figure()
for dérivation in dérivations:
    f, Pxx = spectre(da_bipol.sel(chan = dérivation).values, srate=srate, wsize = 50)
    plt.plot(f, Pxx, label = dérivation)
    plt.legend()
plt.show()

# %%
plt.figure()
for dérivation in dérivations:
    f, Pxx = spectre(da_bipol.sel(chan = dérivation).values, srate=srate, wsize = 50)
    plt.plot(f[:1000], Pxx[:1000], label = dérivation)
    plt.legend()
plt.show()

# %%
da_physios = da.loc[physio_chans,:]

# %%
da_physios
# Out:
# <xarray.DataArray (chan: 21, time: 8135680)>
# array([[-2.57295720e+02, -6.43373541e+02, -1.02032296e+03, ...,
#          1.38447471e+02,  1.50260700e+02,  1.32719844e+02],
#        [ 1.28245136e+02,  3.48132296e+01, -3.13229572e+00, ...,
#          3.64241245e+01,  1.90622568e+01,  7.74124514e+01],
#        [ 3.76143969e+02,  4.99108949e+02,  6.50175097e+02, ...,
#          6.13661479e+02,  7.63474708e+02,  7.01544747e+02],
#        ...,
#        [-3.63607233e-01, -3.64797436e-01, -3.63607233e-01, ...,
#         -3.74319066e-01, -3.75509270e-01, -3.73128862e-01],
#        [ 2.86106661e-01,  3.62401770e-01,  2.86106661e-01, ...,
#          3.62401770e-01,  2.86106661e-01,  3.24254215e-01],
#        [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#          8.23987182e-02,  8.23987182e-02,  8.23987182e-02]])
# Coordinates:
#   * chan     (chan) <U10 'ECG' 'Menton' 'EOGDt' ... 'PRESSION' '-' 'ANNOTATION'
#   * time     (time) float64 0.0 0.003906 0.007812 ... 3.178e+04 3.178e+04

# %%
da_bipol
# Out:
# <xarray.DataArray (chan: 10, time: 8135680)>
# array([[ 150.52918288,  148.20233463,  148.73929961, ...,   36.51361868,
#           32.39688716,   40.98832685],
#        [  69.08949416,   66.22568093,   67.29961089, ...,   79.11284047,
#           77.50194553,   75.53307393],
#        [ -60.85603113,  -53.69649805,  -51.90661479, ..., -107.92996109,
#         -109.71984436, -104.35019455],
#        ...,
#        [ 173.61867704,  175.40856031,  171.64980545, ...,   23.26848249,
#           19.15175097,   22.73151751],
#        [ 374.98054475,  395.38521401,  409.88326848, ...,  305.53307393,
#          306.07003891,  299.62645914],
#        [ 311.61867704,  313.05058366,  299.9844358 , ...,  421.69649805,
#          422.77042802,  417.75875486]])
# Coordinates:
#   * time     (time) float64 0.0 0.003906 0.007812 ... 3.178e+04 3.178e+04
#   * chan     (chan) <U8 'Fp2-C4' 'C4-T4' 'T4-O2' ... 'EOGDt-A2' 'EOGG-A1'

# %%
da_all = xr.concat([da_bipol , da_physios], dim = 'chan')

# %%
da_all.loc[:,20:25].plot.line(x='time', row = 'chan')

# %%
def to_notch_da(da, fs=srate):
    chans = list(da.coords['chan'].values)
    da_notched = da.copy()
    for channel in chans:
        sig = da.sel(chan = channel).values
        sig_notched = notch(sig, fs=fs)
        if channel == 'ECG':
            sig_notched = -sig_notched
        da_notched.loc[channel, :] = sig_notched
    return da_notched

# %%
da_all_notched = to_notch_da(da_all)

# %%
def da_to_mne_object(da, srate=srate):
    ch_names = list(da.coords['chan'].values)
    sfreq = srate
    info = mne.create_info(ch_names, sfreq, ch_types='misc', verbose=None)
    raw = mne.io.RawArray(data = da.values, info=info, first_samp=0, copy='auto', verbose=None)
    return raw

# %%
raw = da_to_mne_object(da_all_notched)
# Out:
# Creating RawArray with float64 data, n_channels=31, n_times=8135680
#     Range : 0 ... 8135679 =      0.000 ... 31779.996 secs
# Ready.

# %%
eeg_names = [ chan for chan in dérivations if not chan in ['EOGDt-A2','EOGG-A1']]
eeg_names
# Out:
# ['Fp2-C4', 'C4-T4', 'T4-O2', 'Fz-Cz', 'Cz-Pz', 'Fp1-C3', 'C3-T3', 'T3-O1']

# %% [markdown]
# ## **YASA**

# %%
txt_hypno_path = root +'cmo/Etudiants/Valentin_G/Sleep_EEG_Respi/data/190722B-AhypnoEXP.txt'

# %%
hypno = np.loadtxt(txt_hypno_path, dtype = str)

# %%
hypno = hypno[:,2]
pd.Series(hypno).value_counts()
# Out:
# N2     419
# W      284
# REM    198
# N3     145
# N1      26
# dtype: int64

# %%
sls = yasa.SleepStaging(raw , eeg_name = 'Fp2-C4' , eog_name = 'EOGG-A1')

# %%
y_pred = sls.predict()
y_pred
# Out:
# /home/valentin.ghibaudo/.virtualenvs/py38_cluster/lib64/python3.8/site-packages/sklearn/base.py:324: UserWarning: Trying to unpickle estimator LabelEncoder from version 0.24.2 when using version 1.0.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# array(['W', 'W', 'W', ..., 'W', 'W', 'W'], dtype=object)

# %%
# # What is the accuracy of the prediction, compared to the human scoring
# accuracy = (hypno == y_pred).sum() / y_pred.size
# print("Theµ overall agreement is %.3f" % accuracy)

# %%
# What are the predicted probabilities of each sleep stage at each epoch?
predict_probas = sls.predict_proba()
predict_probas
# Out:
#              N1        N2        N3         R         W
# epoch
# 0      0.000254  0.000269  0.000013  0.000025  0.999440
# 1      0.000327  0.000246  0.000080  0.000010  0.999338
# 2      0.000059  0.000074  0.000035  0.000013  0.999819
# 3      0.000071  0.000063  0.000002  0.000011  0.999853
# 4      0.000019  0.000018  0.000003  0.000004  0.999956
# ...         ...       ...       ...       ...       ...
# 1054   0.001621  0.001638  0.000111  0.000631  0.995999
# 1055   0.001997  0.001061  0.000054  0.000549  0.996339
# 1056   0.000587  0.001033  0.000096  0.000404  0.997880
# 1057   0.002521  0.007277  0.000209  0.000425  0.989567
# 1058   0.000391  0.000319  0.000116  0.000019  0.999155
#
# [1059 rows x 5 columns]

# %%
# Plot the predicted probabilities
sls.plot_predict_proba();

# %%
# From the probabilities, we can extract a confidence level (ranging from 0 to 1) for each epoch.
confidence = sls.predict_proba().max(1)
confidence
# Out:
# epoch
# 0       0.999440
# 1       0.999338
# 2       0.999819
# 3       0.999853
# 4       0.999956
#           ...
# 1054    0.995999
# 1055    0.996339
# 1056    0.997880
# 1057    0.989567
# 1058    0.999155
# Length: 1059, dtype: float64

# %%
# Let's first create a dataframe with the predicted stages and confidence
df_pred = pd.DataFrame({'Stage': y_pred, 'Confidence': confidence})
df_pred.head(6)

# Now export to a CSV file
# df_pred.to_csv("my_hypno.csv")
# Out:
#       Stage  Confidence
# epoch
# 0         W    0.999440
# 1         W    0.999338
# 2         W    0.999819
# 3         W    0.999853
# 4         W    0.999956
# 5         W    0.999861

# %%
pd.Series(y_pred).value_counts() # IA staging
# Out:
# W     513
# N2    378
# N3     94
# R      72
# N1      2
# dtype: int64

# %%
pd.Series(hypno).value_counts() # human staging
# Out:
# N2     419
# W      284
# REM    198
# N3     145
# N1      26
# dtype: int64

# %% [markdown]
# Note : YASA trouve 1059 époques de 30 secs ce qui est juste en effet étant donné le temps d'enregistrement, alors que le txt human made en note 1072 soit 13 de plus soit 390 secondes de plus soit 6min30 de plus...

# %%
72*30
# Out:
# 2160

# %%
da_all_notched
# Out:
# <xarray.DataArray (chan: 31, time: 8135680)>
# array([[ 1.50529183e+02,  1.50191271e+02,  1.50805315e+02, ...,
#          3.66188653e+01,  3.16137331e+01,  4.09883268e+01],
#        [ 6.90894942e+01,  6.82894568e+01,  6.82945179e+01, ...,
#          7.91938602e+01,  7.83772786e+01,  7.55330739e+01],
#        [-6.08560311e+01, -5.40292796e+01, -5.20637536e+01, ...,
#         -1.07113174e+02, -1.08970853e+02, -1.04350195e+02],
#        ...,
#        [-3.63607233e-01, -3.64502465e-01, -3.63720156e-01, ...,
#         -3.74175733e-01, -3.75263499e-01, -3.73128862e-01],
#        [ 2.86106661e-01,  3.44247424e-01,  2.71594972e-01, ...,
#          3.43329326e-01,  2.67409234e-01,  3.24254215e-01],
#        [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#          8.23987182e-02,  8.23987182e-02,  8.23987182e-02]])
# Coordinates:
#   * time     (time) float64 0.0 0.003906 0.007812 ... 3.178e+04 3.178e+04
#   * chan     (chan) <U10 'Fp2-C4' 'C4-T4' 'T4-O2' ... '-' 'ANNOTATION'

# %%
1057 * 30
# Out:
# 31710

# %%
stages = list(y_pred[:-2])

# %%
epochs = np.arange(0, len(stages), 1)
da_epoched = init_da({'chan':da_all_notched.coords['chan'].values, 'epoch':epochs, 'time':np.arange(0, 30, 1 / srate)})

# %%
da_epoched.shape
# Out:
# (31, 1057, 7680)

# %%
for epoch in epochs:
    start = (epoch) * 30  
    stop = start + 30
    epoch_slice = da_all_notched.loc[:,start:stop].values[:,:-1]
    da_epoched.loc[:, epoch, :] = epoch_slice

# %%
da_epoched
# da_epoched.to_netcdf(root + 'cmo/Etudiants/Valentin_G/Sleep_EEG_Respi/dataarray/da_epoched.nc')
# Out:
# <xarray.DataArray (chan: 31, epoch: 1057, time: 7680)>
# array([[[ 1.50529183e+02,  1.50191271e+02,  1.50805315e+02, ...,
#           4.02067912e+01,  3.78299813e+01,  3.84136926e+01],
#         [ 3.19886293e+01,  3.05814958e+01,  3.00758873e+01, ...,
#           4.76998500e+01,  4.55304535e+01,  3.83030894e+01],
#         [ 3.29630567e+01,  3.54311550e+01,  4.54755706e+01, ...,
#          -2.33207734e+01, -1.70988338e+01, -1.76831824e+01],
#         ...,
#         [ 2.31855283e+01,  2.14085646e+01,  1.73658362e+01, ...,
#           2.27087978e+01,  2.01213332e+01,  2.29258332e+01],
#         [ 2.49667791e+01,  2.37949141e+01,  1.80767969e+01, ...,
#           2.26988889e+01,  3.00008530e+01,  3.51644186e+01],
#         [ 4.53305468e+01,  4.95480249e+01,  4.72687952e+01, ...,
#           4.74378435e+01,  4.22493246e+01,  4.91851192e+01]],
#
#        [[ 6.90894942e+01,  6.82894568e+01,  6.82945179e+01, ...,
#           6.43402774e+01,  5.98643723e+01,  5.23955086e+01],
#         [ 5.47619405e+01,  5.28580376e+01,  4.67988261e+01, ...,
#           5.86189512e+01,  6.32025281e+01,  6.10016355e+01],
#         [ 6.13050162e+01,  6.49400759e+01,  4.87306715e+01, ...,
#           5.52349115e+01,  5.83684146e+01,  6.16451043e+01],
# ...
#         [ 2.71772304e-01,  3.34632965e-01,  2.74928300e-01, ...,
#           3.71578280e-01,  3.94792854e-01,  4.10290594e-01],
#         [ 3.80069201e-01,  3.71718920e-01,  3.28221165e-01, ...,
#           4.12964747e-01,  3.99462995e-01,  3.52280003e-01],
#         [ 3.35734957e-01,  3.90192083e-01,  4.13426875e-01, ...,
#           2.83632792e-01,  2.96872871e-01,  3.02782408e-01]],
#
#        [[ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#           8.23987182e-02,  8.23987182e-02,  8.23987182e-02],
#         [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#           8.23987182e-02,  8.23987182e-02,  8.23987182e-02],
#         [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#           8.23987182e-02,  8.23987182e-02,  8.23987182e-02],
#         ...,
#         [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#           8.23987182e-02,  8.23987182e-02,  8.23987182e-02],
#         [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#           8.23987182e-02,  8.23987182e-02,  8.23987182e-02],
#         [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#           8.23987182e-02,  8.23987182e-02,  8.23987182e-02]]])
# Coordinates:
#   * chan     (chan) <U10 'Fp2-C4' 'C4-T4' 'T4-O2' ... '-' 'ANNOTATION'
#   * epoch    (epoch) int64 0 1 2 3 4 5 6 ... 1050 1051 1052 1053 1054 1055 1056
#   * time     (time) float64 0.0 0.003906 0.007812 0.01172 ... 29.99 29.99 30.0

# %%
da_epoched.loc['Fp2-C4',:,:].plot()

# %%
midx = [epochs, stages]
midx_ready = pd.MultiIndex.from_arrays(midx, names=('epochs', 'stages'))
da_epoched_midx = da_epoched.assign_coords(coords = {'epoch':midx_ready})

# %%
da_epoched_midx
# Out:
# <xarray.DataArray (chan: 31, epoch: 1057, time: 7680)>
# array([[[ 1.50529183e+02,  1.50191271e+02,  1.50805315e+02, ...,
#           4.02067912e+01,  3.78299813e+01,  3.84136926e+01],
#         [ 3.19886293e+01,  3.05814958e+01,  3.00758873e+01, ...,
#           4.76998500e+01,  4.55304535e+01,  3.83030894e+01],
#         [ 3.29630567e+01,  3.54311550e+01,  4.54755706e+01, ...,
#          -2.33207734e+01, -1.70988338e+01, -1.76831824e+01],
#         ...,
#         [ 2.31855283e+01,  2.14085646e+01,  1.73658362e+01, ...,
#           2.27087978e+01,  2.01213332e+01,  2.29258332e+01],
#         [ 2.49667791e+01,  2.37949141e+01,  1.80767969e+01, ...,
#           2.26988889e+01,  3.00008530e+01,  3.51644186e+01],
#         [ 4.53305468e+01,  4.95480249e+01,  4.72687952e+01, ...,
#           4.74378435e+01,  4.22493246e+01,  4.91851192e+01]],
#
#        [[ 6.90894942e+01,  6.82894568e+01,  6.82945179e+01, ...,
#           6.43402774e+01,  5.98643723e+01,  5.23955086e+01],
#         [ 5.47619405e+01,  5.28580376e+01,  4.67988261e+01, ...,
#           5.86189512e+01,  6.32025281e+01,  6.10016355e+01],
#         [ 6.13050162e+01,  6.49400759e+01,  4.87306715e+01, ...,
#           5.52349115e+01,  5.83684146e+01,  6.16451043e+01],
# ...
#         [ 2.71772304e-01,  3.34632965e-01,  2.74928300e-01, ...,
#           3.71578280e-01,  3.94792854e-01,  4.10290594e-01],
#         [ 3.80069201e-01,  3.71718920e-01,  3.28221165e-01, ...,
#           4.12964747e-01,  3.99462995e-01,  3.52280003e-01],
#         [ 3.35734957e-01,  3.90192083e-01,  4.13426875e-01, ...,
#           2.83632792e-01,  2.96872871e-01,  3.02782408e-01]],
#
#        [[ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#           8.23987182e-02,  8.23987182e-02,  8.23987182e-02],
#         [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#           8.23987182e-02,  8.23987182e-02,  8.23987182e-02],
#         [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#           8.23987182e-02,  8.23987182e-02,  8.23987182e-02],
#         ...,
#         [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#           8.23987182e-02,  8.23987182e-02,  8.23987182e-02],
#         [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#           8.23987182e-02,  8.23987182e-02,  8.23987182e-02],
#         [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#           8.23987182e-02,  8.23987182e-02,  8.23987182e-02]]])
# Coordinates:
#   * chan     (chan) <U10 'Fp2-C4' 'C4-T4' 'T4-O2' ... '-' 'ANNOTATION'
#   * epoch    (epoch) MultiIndex
#   - epochs   (epoch) int64 0 1 2 3 4 5 6 ... 1050 1051 1052 1053 1054 1055 1056
#   - stages   (epoch) object 'W' 'W' 'W' 'W' 'W' 'W' ... 'W' 'W' 'W' 'W' 'W' 'W'
#   * time     (time) float64 0.0 0.003906 0.007812 0.01172 ... 29.99 29.99 30.0

# %%
y_pred
# Out:
# array(['W', 'W', 'W', ..., 'W', 'W', 'W'], dtype=object)

# %%
y_pred
# Out:
# array(['W', 'W', 'W', ..., 'W', 'W', 'W'], dtype=object)

# %%
y_pred_series = pd.Series(y_pred)
y_pred_series.value_counts()
# Out:
# W     513
# N2    378
# N3     94
# R      72
# N1      2
# dtype: int64

# %%
stades = []
for i, stade in enumerate(y_pred_series):
    if not i == 0:
        if stade == y_pred_series[i-1]:
            stades.append(stade)

# %%
len(stades)
# Out:
# 956

# %%
da_epoched_midx.sel(stages = 'N2', chan = dérivations).loc[:,123:150,:].plot.line(x='time', row = 'epochs', col = 'chan')

# %%
def stack_stages(da_midx, stage, srate = srate):
    da = da_midx.sel(stages = stage)
    epochs = list(da.coords['epochs'].values)
    to_concat = []
    for epoch in epochs:
        da_epoch = da.sel(epochs = epoch).reset_coords(drop=True)
        to_concat.append(da_epoch)
    da_concat = xr.concat(to_concat, dim = 'time')
    time_vector = np.arange(0,da_concat.shape[1]/srate, 1/srate)
    da_return = da_concat.assign_coords({'time':time_vector}) 
    return da_return

# %%
da_stacked_stage = stack_stages(da_midx = da_epoched_midx, stage='N2')

# %%
da_stacked_stage
# Out:
# <xarray.DataArray (chan: 31, time: 2903040)>
# array([[ 1.57316828e+01,  1.21813412e+01,  9.38920537e+00, ...,
#          4.13026381e+01,  4.20410044e+01,  4.21016577e+01],
#        [ 5.83001757e+01,  5.72083252e+01,  5.58677758e+01, ...,
#          6.90338347e+01,  7.26383614e+01,  7.55347086e+01],
#        [-1.19060935e+02, -1.19908883e+02, -1.20117212e+02, ...,
#         -7.11896059e+01, -7.09296860e+01, -7.19917447e+01],
#        ...,
#        [-3.68261630e-01, -3.65724343e-01, -3.68702077e-01, ...,
#         -3.75527809e-01, -3.77589380e-01, -3.75654328e-01],
#        [ 2.69694168e-01,  2.59228093e-01,  2.38982679e-01, ...,
#          3.01306945e-01,  3.82575387e-01,  2.98738856e-01],
#        [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#          8.23987182e-02,  8.23987182e-02,  8.23987182e-02]])
# Coordinates:
#   * chan     (chan) <U10 'Fp2-C4' 'C4-T4' 'T4-O2' ... '-' 'ANNOTATION'
#   * time     (time) float64 0.0 0.003906 0.007812 ... 1.134e+04 1.134e+04

# %%
stages = list(set(y_pred))

# %%
def stack_all_stages(da_midx, stages=stages, srate=srate):
    concat = []
    for stage in stages:
        da_stage = stack_stages(da_midx=da_midx, stage=stage, srate = srate)
        concat.append(da_stage)
    da_all_stages = xr.concat(concat, dim = 'stage')
    da_all_stages = da_all_stages.assign_coords({'stage':stages})
    return da_all_stages

# %%
da_all_stages = stack_all_stages(da_midx=da_epoched_midx)

# %%
da_all_stages
# Out:
# <xarray.DataArray (stage: 5, chan: 31, time: 3924480)>
# array([[[ 1.57316828e+01,  1.21813412e+01,  9.38920537e+00, ...,
#                      nan,             nan,             nan],
#         [ 5.83001757e+01,  5.72083252e+01,  5.58677758e+01, ...,
#                      nan,             nan,             nan],
#         [-1.19060935e+02, -1.19908883e+02, -1.20117212e+02, ...,
#                      nan,             nan,             nan],
#         ...,
#         [-3.68261630e-01, -3.65724343e-01, -3.68702077e-01, ...,
#                      nan,             nan,             nan],
#         [ 2.69694168e-01,  2.59228093e-01,  2.38982679e-01, ...,
#                      nan,             nan,             nan],
#         [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#                      nan,             nan,             nan]],
#
#        [[ 9.72816700e+00,  1.12047267e+01,  1.24118174e+01, ...,
#                      nan,             nan,             nan],
#         [ 5.09937705e+01,  4.90444414e+01,  4.72933498e+01, ...,
#                      nan,             nan,             nan],
#         [-6.25459270e+01, -5.86669804e+01, -5.60065717e+01, ...,
#                      nan,             nan,             nan],
# ...
#         [-3.63607233e-01, -3.64502465e-01, -3.63720156e-01, ...,
#          -3.74177658e-01, -3.74226240e-01, -3.71045281e-01],
#         [ 2.86106661e-01,  3.44247424e-01,  2.71594972e-01, ...,
#           2.83632792e-01,  2.96872871e-01,  3.02782408e-01],
#         [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#           8.23987182e-02,  8.23987182e-02,  8.23987182e-02]],
#
#        [[ 3.82657269e+01,  3.81343494e+01,  3.84238475e+01, ...,
#                      nan,             nan,             nan],
#         [ 4.57486231e+01,  4.59503743e+01,  4.72195541e+01, ...,
#                      nan,             nan,             nan],
#         [-6.88179253e+01, -6.79525058e+01, -6.83767988e+01, ...,
#                      nan,             nan,             nan],
#         ...,
#         [-3.69689764e-01, -3.68390807e-01, -3.68480827e-01, ...,
#                      nan,             nan,             nan],
#         [ 2.35492119e-01,  2.89770504e-01,  2.17274226e-01, ...,
#                      nan,             nan,             nan],
#         [ 8.23987182e-02,  8.23987182e-02,  8.23987182e-02, ...,
#                      nan,             nan,             nan]]])
# Coordinates:
#   * time     (time) float64 0.0 0.003906 0.007812 ... 1.533e+04 1.533e+04
#   * chan     (chan) <U10 'Fp2-C4' 'C4-T4' 'T4-O2' ... '-' 'ANNOTATION'
#   * stage    (stage) <U2 'N2' 'R' 'N3' 'W' 'N1'

# %%
get_memory(da_all_stages)
# Out:
# 4.8663552 Go

# %%
def get_rsp_by_stade(da_all=da_all_stages, stages=stages):
    for stage in stages: 
        da_sel = da_all.sel(stage=stage).dropna(dim='time')
        print( stage , da_sel.coords['time'].values[-1])

# %%
get_rsp_by_stade()
# Out:
# N2 11339.99609375
# R 2159.99609375
# N3 2819.99609375
# W 15329.99609375
# N1 59.99609375

# %%
da_all_stages.loc['N1','Fp2-C4',0:100].plot.line(x='time', hue = 'stage')

# %%
da_all_stages.loc['N1','ECG',:].plot()

# %%
da_all_stages.loc['N1',['EOGG','EOGG-A1'],30:50].plot.line(x='time', hue='chan')
# Out:
# [<matplotlib.lines.Line2D at 0x7f735f6e7df0>,
#  <matplotlib.lines.Line2D at 0x7f735f6e7e50>]

# %%
# da_all_stages.to_netcdf(root + 'cmo/Etudiants/Valentin_G/Sleep_EEG_Respi/dataarray/da_staged.nc')

# %%
srate
# Out:
# 256.0

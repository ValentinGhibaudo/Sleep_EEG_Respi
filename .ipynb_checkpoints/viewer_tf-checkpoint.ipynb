# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from scipy import signal
import matplotlib.pyplot as plt
import xarray as xr
import ghibtools as gh
from params import *

# %%
save = True

# %%
def get_cycles_num(patient, mean):
    ser = pd.read_excel(f'../df_analyse/cycles_numbers_{patient}.xlsx', index_col = 0).T.set_index('patient')
    return ser.loc[patient, mean]

# %%
da = xr.load_dataarray(f'../dataarray/da_tf_all_means.nc')

# %%
da
# Out:
# <xarray.DataArray (patient: 10, cycle_type: 4, freqs: 40, point: 1000)>
# array([[[[ 2.37006009e-01,  2.36621156e-01,  2.36236289e-01, ...,
#            2.37797469e-01,  2.37539649e-01,  2.37269595e-01],
#          [ 1.93936363e-01,  1.93439364e-01,  1.92937866e-01, ...,
#            1.94906890e-01,  1.94588363e-01,  1.94256753e-01],
#          [ 1.59938693e-01,  1.59410179e-01,  1.58875346e-01, ...,
#            1.60913944e-01,  1.60594955e-01,  1.60262227e-01],
#          ...,
#          [-3.05449218e-01, -3.05457383e-01, -3.05468351e-01, ...,
#           -3.05363685e-01, -3.05392951e-01, -3.05422843e-01],
#          [-3.06734413e-01, -3.06739599e-01, -3.06747466e-01, ...,
#           -3.06656539e-01, -3.06678653e-01, -3.06704044e-01],
#          [-3.08001906e-01, -3.07998955e-01, -3.08000386e-01, ...,
#           -3.07944924e-01, -3.07956904e-01, -3.07970524e-01]],
#
#         [[ 1.95451841e-01,  1.93900973e-01,  1.92268848e-01, ...,
# ...

# %%
for mode in da.coords['cycle_type'].values:
    fig, axs = plt.subplots(ncols = 5, nrows = 2, constrained_layout = True, figsize = (20,8))
    fig.suptitle(f'Mean normalized respiration cycle Phase-Frequency Plot : cycles = {mode}', fontsize = 20, y = 1.05)
    for row, sublists in enumerate([ patients[:5] , patients[5:] ]): 
        for col, patient in enumerate(sublists):
            ax = axs[row, col]
            min_freq = 11
            max_freq = 17
            data = da.loc[patient, mode , min_freq:max_freq,:].values
            ax.pcolormesh(da.coords['point'], da.coords['freqs'].loc[min_freq:max_freq], data)
            ax.set_title(patient)
            ax.set_ylabel('Freq [Hz]')
            ax.set_xlabel('Respiration Cycle Phase')
            ax.vlines(x = 300, ymin = min_freq, ymax=max_freq, color = 'r')
            ax.set_xticks([150,300,650])
            ax.set_xticklabels(['inspi','i-e transition','expi'], rotation=45, fontsize=10)
    if save:
        plt.savefig(f'../presentation_4/stretch_tf_by_patient_{mode}', bbox_inches = 'tight')
    plt.show()

# %%
for mode in da.coords['cycle_type'].values:
    fig, axs = plt.subplots(ncols = 5, nrows = 2, constrained_layout = True, figsize = (20,8))
    fig.suptitle(f'Mean respiration cycle normalized Sigma Power : cycles = {mode}', fontsize = 20, y = 1.05)
    for row, sublists in enumerate([ patients[:5] , patients[5:] ]): 
        for col, patient in enumerate(sublists):
            ax = axs[row, col]
            min_freq = 11
            max_freq = 16
            data = da.loc[patient, mode , min_freq:max_freq,:].mean('freqs').values
            ax.plot(da.coords['point'], data)
            ax.set_title(patient)
            ax.set_ylabel('Sigma Power')
            ax.set_xlabel('Respiration Cycle Phase')
            ax.vlines(x = 300, ymin = min(data), ymax=max(data), color = 'r')
            ax.set_xticks([150,300,650])
            ax.set_xticklabels(['inspi','i-e transition','expi'], rotation=45, fontsize=8)
    if save:
        plt.savefig(f'../presentation_4/stretch_sigma_power_by_patient_{mode}', bbox_inches = 'tight')
    plt.show()

# %%
fig, ax = plt.subplots(constrained_layout = True, figsize = (10,7))
min_freq = 11
max_freq = 16
data = da.loc[:, 'spindled' , min_freq:max_freq,:].mean(['patient','freqs']).values
ax.plot(da.coords['point'], data)
ax.set_title('Mean Patient * Spindled respiration cycles normalized Sigma Power')
ax.set_ylabel('Sigma Power')
ax.set_xlabel('Respiration Cycle Phase')
ax.vlines(x = 300, ymin = min(data), ymax=max(data), color = 'r')
ax.set_xticks([150,300,650])
ax.set_xticklabels(['inspi','i-e transition','expi'], rotation=45, fontsize=10)
if save:
    plt.savefig(f'../presentation_4/stretch_sigma_power_mean_patient', bbox_inches = 'tight')
plt.show()

# %%
fig, ax = plt.subplots(constrained_layout = True, figsize = (15,8))
min_freq = 11
max_freq = 16
data = da.loc[:, 'diff' , min_freq:max_freq,:].mean('patient').values
ax.pcolormesh( da.coords['point'] , da.coords['freqs'].loc[min_freq:max_freq] , data)
ax.set_title('Mean Patient * respiration cycles normalized Phase-Frequency Plot : cycles = diff ', fontsize = 20, y = 1.05)
ax.set_ylabel('Sigma Power')
ax.set_xlabel('Respiration Cycle Phase')
ax.vlines(x = 300, ymin = min_freq, ymax=max_freq, color = 'r')
ax.set_xticks([150,300,650])
ax.set_xticklabels(['inspi','i-e transition','expi'], rotation=45, fontsize=10)
if save:
    plt.savefig(f'../presentation_4/stretch_tf_mean_patient_diff', bbox_inches = 'tight')
plt.show()

# %%
fig, axs = plt.subplots(ncols = 4, constrained_layout = True, figsize = (20,5))
fig.suptitle('Mean Patient * respiration cycles normalized Phase-Frequency Plot', fontsize = 20, y = 1.05)
min_freq = 11
max_freq = 16

for col, mode in enumerate(da.coords['cycle_type'].values):
    ax = axs[col]
    data = da.loc[:, mode , min_freq:max_freq,:].mean('patient').values
    ax.pcolormesh( da.coords['point'] , da.coords['freqs'].loc[min_freq:max_freq] , data)
    ax.set_title(mode)
    ax.set_ylabel('Freq [Hz]')
    ax.set_xlabel('Respiration Cycle Phase')
    ax.vlines(x = 300, ymin = min_freq, ymax=max_freq, color = 'r')
    ax.set_xticks([150,300,650])
    ax.set_xticklabels(['inspi','i-e transition','expi'], rotation=45, fontsize=10)
if save:
    plt.savefig(f'../presentation_4/stretch_tf_mean_patient_modes', bbox_inches = 'tight')
plt.show()

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from params import patients, dpis

# %%
# for patient in patients:
#     print(patient)
#     phase_freqs = xr.open_dataarray(f'../sigma_coupling/{patient}_phase_freq_sigma.nc') # 5 D xarray : chan * zscoring * cycle * freq * time
#     print(phase_freqs.coords['cycle'].size)
#     phase_freq_mean_cycle = phase_freqs.mean('cycle')
#     del phase_freqs
#     phase_freq_mean_cycle.sel(zscoring = 'raw').plot.pcolormesh(x = 'point', y = 'freq', col = 'chan', col_wrap = 4, add_colorbar = True)
#     plt.savefig(f'../sigma_coupling_figures/{patient}_phase_freq.tif', bbox_inches = 'tight', dpi = dpis)
#     plt.close()

# %%
patient = 'P1'

# %%
phase_freqs = xr.open_dataarray(f'../sigma_coupling/{patient}_phase_freq_sigma.nc')

# %%
phase_freqs
# Out:
# <xarray.DataArray (chan: 8, cycle: 5299, freq: 30, point: 1000)>
# [1271760000 values with dtype=float64]
# Coordinates:
#   * chan     (chan) object 'Fp2-C4' 'Fz-Cz' 'Fp1-C3' ... 'Cz-Pz' 'T4-O2' 'T3-O1'
#   * cycle    (cycle) int64 0 1 2 3 4 5 6 ... 5292 5293 5294 5295 5296 5297 5298
#   * freq     (freq) float64 10.0 10.21 10.41 10.62 ... 15.38 15.59 15.79 16.0
#   * point    (point) int64 0 1 2 3 4 5 6 7 8 ... 992 993 994 995 996 997 998 999
# Attributes:
#     clipped_times:    [ 3450.81640625  3450.8203125   3450.82421875 ... 27838...
#     times_to_cycles:  [0.00000000e+00 1.27388535e-03 2.54777070e-03 ... 5.299...
#     cycle_points:     [0.000000e+00 1.000000e-03 2.000000e-03 ... 5.298997e+0...

# %%
phase_freqs.loc['C4-T4',:,:,:].mean('cycle').plot()

# %%
phase_freqs.attrs['clipped_times']
# Out:
# array([ 3450.81640625,  3450.8203125 ,  3450.82421875, ...,
#        27838.234375  , 27838.23828125, 27838.2421875 ])

# %%
phase_freqs.attrs['times_to_cycles']
# Out:
# array([0.00000000e+00, 1.27388535e-03, 2.54777070e-03, ...,
#        5.29999649e+03, 5.29999766e+03, 5.29999883e+03])

# %%
phase_freqs.coords['cycle'].shape
# Out:
# (5299,)
